# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

agent = Agent(name="Jokester", instructions="You are world's best Autonomous AI Agent planner", model="gpt-5-nano")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("planning  of a agentic ai system"):
    result = await Runner.run(agent, "plan to build Autonomous AI Agents")
    print(result.final_output)
# Out:
# Below is a practical, end-to-end plan to design, build, and operationalize autonomous AI agents. It covers scope, architecture, tech stack, lifecycle, safety, and milestones. You can adapt it to a single agent or a fleet of agents across domains.
#
# 1) Define scope and success criteria
# - Problem statement: What problem do you want autonomous agents to solve? (e.g., automate repetitive business tasks, intelligent assistants for analysts, autonomous data collection and synthesis)
# - Constraints: latency, compute budget, data privacy, regulatory compliance, safety requirements.
# - Success metrics: accuracy, time saved, cost reduction, user satisfaction, reliability (uptime), safety incidents per month.
# - Boundaries: what agents can and cannot do without human-in-the-loop (HITL). Define kill-switch policies.
#
# 2) Core architectural principles
# - Deliberative + reactive hybrid: use planning for long-horizon tasks, reactive policies for immediate safety and control.
# ...

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
